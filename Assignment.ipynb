# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Dura E Shehwar
# Research Analyst

# %% [markdown]
# *I wanted to be a research analyst due to my curiosity of working with data and numbers and background in mathematics
# As it the field where i can find myself to be using my skills wholely*

# %% [markdown]
# ### The following code will plot the line by given point in a and b

# %%
a=[0,2,4,6,8,10]
b=[0,4,16,36,64,100]
import matplotlib.pyplot as plt
plt.plot(a,b)
plt.show()

# %% [markdown]
#  ### Table
# | Course      | Time period |
# | ----------- | ----------- |
# | Calculus    | 3 hours     |
# | Economics   | 2 hours     |
#
#  ### Syntax/code highlighting
#
# ```json
# {
#   "Name": "Shehwar",
#   "Age": 20,
#   "Occupation": "Student"
# }
# ```
#  ### Hyperlink
#
# https://www.coursera.org/learn/open-source-tools-for-data-science/ungradedWidget/c1F5I/instructions-create-and-share-your-jupyter-notebook
